# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhutsang/Baocaogiuaky/blob/main/CNNFlower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/TrainAI/Flower/datatrain/'

img_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('daisy'):
    output = 1.0
  if file.startswith('dandelion'):
    output = 2.0
  if file.startswith('rose'):
    output = 3.0
  if file.startswith('sunflower'):
    output = 4.0
  if file.startswith('tulip'):
    output = 5.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# Out:
# (336, 100, 100, 3) (336,)

# %%
photos = photos.astype('float32')/255.0

print(photos.shape)
# Out:
# (336, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)
(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (201, 100, 100, 3)
# (201,)
# (68, 100, 100, 3)
# (68,)
# (67, 100, 100, 3)
# (67,)

# %%
image_test= 150
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Hoa này là: ', trainY[image_test])
# Out:
# Hoa này là:  5.0

# %%
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (201, 6)
# (68, 6)
# (67, 6)

# %%
batch_size=32
epochs=50
classes = 6

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'linear', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))


# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))
     
# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2,863,046
# Trainable params: 2,863,046
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 6s 788ms/step - loss: 1.7906 - accuracy: 0.3582 - val_loss: 1.4308 - val_accuracy: 0.3284
# Epoch 2/50
# 7/7 [==============================] - 7s 991ms/step - loss: 1.3019 - accuracy: 0.4826 - val_loss: 1.3834 - val_accuracy: 0.3134
# Epoch 3/50
# 7/7 [==============================] - 5s 704ms/step - loss: 1.1495 - accuracy: 0.5274 - val_loss: 1.2808 - val_accuracy: 0.4925
# Epoch 4/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.9388 - accuracy: 0.6318 - val_loss: 1.0933 - val_accuracy: 0.5373
# Epoch 5/50
# 7/7 [==============================] - 5s 744ms/step - loss: 0.8163 - accuracy: 0.6965 - val_loss: 1.0419 - val_accuracy: 0.5970
# Epoch 6/50
# 7/7 [==============================] - 6s 885ms/step - loss: 0.6859 - accuracy: 0.7313 - val_loss: 1.1387 - val_accuracy: 0.5522
# Epoch 7/50
# 7/7 [==============================] - 6s 836ms/step - loss: 0.6189 - accuracy: 0.7861 - val_loss: 1.1087 - val_accuracy: 0.5672
# Epoch 8/50
# 7/7 [==============================] - 5s 748ms/step - loss: 0.5233 - accuracy: 0.8109 - val_loss: 1.2783 - val_accuracy: 0.5970
# Epoch 9/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.4328 - accuracy: 0.8408 - val_loss: 1.1918 - val_accuracy: 0.5821
# Epoch 10/50
# 7/7 [==============================] - 5s 733ms/step - loss: 0.2632 - accuracy: 0.9353 - val_loss: 1.8870 - val_accuracy: 0.5522
# Epoch 11/50
# 7/7 [==============================] - 6s 950ms/step - loss: 0.2405 - accuracy: 0.9154 - val_loss: 1.4114 - val_accuracy: 0.6119
# Epoch 12/50
# 7/7 [==============================] - 6s 707ms/step - loss: 0.1417 - accuracy: 0.9751 - val_loss: 1.4841 - val_accuracy: 0.6269
# Epoch 13/50
# 7/7 [==============================] - 5s 722ms/step - loss: 0.0868 - accuracy: 0.9751 - val_loss: 1.8616 - val_accuracy: 0.6269
# Epoch 14/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0467 - accuracy: 0.9900 - val_loss: 2.1911 - val_accuracy: 0.5224
# Epoch 15/50
# 7/7 [==============================] - 6s 844ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 2.4939 - val_accuracy: 0.6418
# Epoch 16/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0234 - accuracy: 0.9950 - val_loss: 2.2481 - val_accuracy: 0.6418
# Epoch 17/50
# 7/7 [==============================] - 5s 726ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 2.6830 - val_accuracy: 0.5373
# Epoch 18/50
# 7/7 [==============================] - 5s 742ms/step - loss: 0.0313 - accuracy: 0.9950 - val_loss: 2.0576 - val_accuracy: 0.5821
# Epoch 19/50
# 7/7 [==============================] - 7s 941ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 3.0337 - val_accuracy: 0.4627
# Epoch 20/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 2.7362 - val_accuracy: 0.5970
# Epoch 21/50
# 7/7 [==============================] - 7s 962ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 2.6984 - val_accuracy: 0.5522
# Epoch 22/50
# 7/7 [==============================] - 5s 729ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 2.9849 - val_accuracy: 0.4925
# Epoch 23/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 3.0666 - val_accuracy: 0.4925
# Epoch 24/50
# 7/7 [==============================] - 5s 696ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.7362 - val_accuracy: 0.5672
# Epoch 25/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.8495 - val_accuracy: 0.5075
# Epoch 26/50
# 7/7 [==============================] - 6s 788ms/step - loss: 8.8822e-04 - accuracy: 1.0000 - val_loss: 3.0607 - val_accuracy: 0.4925
# Epoch 27/50
# 7/7 [==============================] - 5s 714ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.1022 - val_accuracy: 0.4925
# Epoch 28/50
# 7/7 [==============================] - 7s 1s/step - loss: 7.5787e-04 - accuracy: 1.0000 - val_loss: 3.0418 - val_accuracy: 0.4925
# Epoch 29/50
# 7/7 [==============================] - 5s 728ms/step - loss: 5.1197e-04 - accuracy: 1.0000 - val_loss: 3.0112 - val_accuracy: 0.5224
# Epoch 30/50
# 7/7 [==============================] - 7s 1s/step - loss: 4.5997e-04 - accuracy: 1.0000 - val_loss: 3.0357 - val_accuracy: 0.5224
# Epoch 31/50
# 7/7 [==============================] - 5s 694ms/step - loss: 3.8890e-04 - accuracy: 1.0000 - val_loss: 3.0785 - val_accuracy: 0.5224
# Epoch 32/50
# 7/7 [==============================] - 5s 734ms/step - loss: 3.3326e-04 - accuracy: 1.0000 - val_loss: 3.1384 - val_accuracy: 0.5075
# Epoch 33/50
# 7/7 [==============================] - 7s 1s/step - loss: 3.1362e-04 - accuracy: 1.0000 - val_loss: 3.1758 - val_accuracy: 0.5075
# Epoch 34/50
# 7/7 [==============================] - 5s 700ms/step - loss: 2.9260e-04 - accuracy: 1.0000 - val_loss: 3.1907 - val_accuracy: 0.5224
# Epoch 35/50
# 7/7 [==============================] - 7s 1s/step - loss: 2.6668e-04 - accuracy: 1.0000 - val_loss: 3.1964 - val_accuracy: 0.5224
# Epoch 36/50
# 7/7 [==============================] - 5s 741ms/step - loss: 2.4686e-04 - accuracy: 1.0000 - val_loss: 3.2097 - val_accuracy: 0.5224
# Epoch 37/50
# 7/7 [==============================] - 5s 741ms/step - loss: 2.3327e-04 - accuracy: 1.0000 - val_loss: 3.2298 - val_accuracy: 0.5373
# Epoch 38/50
# 7/7 [==============================] - 7s 932ms/step - loss: 2.2061e-04 - accuracy: 1.0000 - val_loss: 3.2498 - val_accuracy: 0.5373
# Epoch 39/50
# 7/7 [==============================] - 5s 752ms/step - loss: 2.1037e-04 - accuracy: 1.0000 - val_loss: 3.2672 - val_accuracy: 0.5373
# Epoch 40/50
# 7/7 [==============================] - 7s 1s/step - loss: 1.9908e-04 - accuracy: 1.0000 - val_loss: 3.2892 - val_accuracy: 0.5373
# Epoch 41/50
# 7/7 [==============================] - 5s 741ms/step - loss: 1.9144e-04 - accuracy: 1.0000 - val_loss: 3.3091 - val_accuracy: 0.5373
# Epoch 42/50
# 7/7 [==============================] - 5s 736ms/step - loss: 1.8332e-04 - accuracy: 1.0000 - val_loss: 3.3215 - val_accuracy: 0.5373
# Epoch 43/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.7479e-04 - accuracy: 1.0000 - val_loss: 3.3307 - val_accuracy: 0.5522
# Epoch 44/50
# 7/7 [==============================] - 5s 702ms/step - loss: 1.6866e-04 - accuracy: 1.0000 - val_loss: 3.3387 - val_accuracy: 0.5522
# Epoch 45/50
# 7/7 [==============================] - 6s 920ms/step - loss: 1.6147e-04 - accuracy: 1.0000 - val_loss: 3.3438 - val_accuracy: 0.5522
# Epoch 46/50
# 7/7 [==============================] - 6s 805ms/step - loss: 1.5537e-04 - accuracy: 1.0000 - val_loss: 3.3525 - val_accuracy: 0.5522
# Epoch 47/50
# 7/7 [==============================] - 5s 729ms/step - loss: 1.5103e-04 - accuracy: 1.0000 - val_loss: 3.3665 - val_accuracy: 0.5522
# Epoch 48/50
# 7/7 [==============================] - 7s 1s/step - loss: 1.4506e-04 - accuracy: 1.0000 - val_loss: 3.3763 - val_accuracy: 0.5522
# Epoch 49/50
# 7/7 [==============================] - 5s 698ms/step - loss: 1.3986e-04 - accuracy: 1.0000 - val_loss: 3.3815 - val_accuracy: 0.5522
# Epoch 50/50
# 7/7 [==============================] - 6s 926ms/step - loss: 1.3516e-04 - accuracy: 1.0000 - val_loss: 3.3907 - val_accuracy: 0.5522
# 322.85962557792664

# %%
model.save('/content/drive/MyDrive/TrainAI/Flower/modelflower')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')


plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training ')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
name= {1:'daisy', 2:'dandelion',3:'rose',4:'sunflower',5:'tulip'}  
#test
filePath = '/content/drive/MyDrive/TrainAI/Flower/Check/tulip.jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 136ms/step
# Predicted:  rose

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=68, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 3/3 [==============================] - 0s 107ms/step
# Accuracy: 63.23529411764706 %
