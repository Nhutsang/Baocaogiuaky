# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhutsang/Baocaogiuaky/blob/main/CNNFLower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from numpy import asarray,save
from sklearn.model_selection import train_test_split
from time import time
from keras.utils import load_img, img_to_array
from keras.utils  import to_categorical
from keras.models import Sequential, Model
from keras.layers import *
from keras.layers import LeakyReLU
from keras.optimizers import Adam
from keras.engine.training import optimizers
from keras.backend import categorical_crossentropy

# %%
folder = '/content/drive/MyDrive/TrainAI/Flower/datatrain/'

iimg_size = 100;
photos, labels = list(), list()
for file in listdir(folder) :
  output = 0.0
  if file.startswith('daisy'):
    output = 1.0
  if file.startswith('dandelion'):
    output = 2.0
  if file.startswith('rose'):
    output = 3.0
  if file.startswith('sunflower'):
    output = 4.0
  if file.startswith('tulip'):
    output = 5.0
  
  photo = load_img(folder + file, target_size = (img_size,img_size))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)
photos = asarray(photos)
labels = np.array(labels)
print(photos.shape, labels.shape)
# Out:
# (336, 100, 100, 3) (336,)

# %%
photos = photos.astype('float32')/255.0

print(photos.shape)
# Out:
# (336, 100, 100, 3)

# %%
(trainX, testX, trainY, testY) = train_test_split(photos, labels, test_size=0.20, stratify=labels, random_state=10)
(trainX, valX, trainY, valY) = train_test_split(trainX, trainY, test_size=0.25, random_state=10)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
print(valX.shape)
print(valY.shape)
# Out:
# (201, 100, 100, 3)
# (201,)
# (68, 100, 100, 3)
# (68,)
# (67, 100, 100, 3)
# (67,)

# %%
image_test= 150
hinh = trainX[image_test]
plt.imshow(hinh) 
plt.show()  
print('Hoa này là: ', trainY[image_test])
# Out:
# Hoa này là:  5.0

# %%
for i in range(16):  # 25 hình ảnh
  plt.subplot(4,4,i+1) # 5 cột , 5 hàng
  plt.tight_layout()
  plt.imshow(trainX[i], interpolation='none')
  plt.title('so:{}'.format(trainY[i]))
  plt.xticks([])
  plt.yticks([])

# %%
trainY = to_categorical (trainY)
testY=to_categorical(testY)
valY=to_categorical(valY)

print(trainY.shape)
print(testY.shape)
print(valY.shape)
# Out:
# (201, 6)
# (68, 6)
# (67, 6)

# %%
batch_size=32
epochs=50
classes = 6

#Tạo 1 mạng có 28x28 input và 10 output
model = Sequential()

# 1 bộ VGG
model.add(Conv2D(32, kernel_size=(3,3), activation = 'linear', input_shape=(img_size,img_size,3),padding = 'same'))
model.add(LeakyReLU(alpha=0.1))  # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding='same'))


# Bộ 2 VGG
model.add(Conv2D(64,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))


# Bộ 3 VGG
model.add(Conv2D(128,(3,3) , activation = 'linear' , padding = 'same'))
model.add(LeakyReLU(alpha = 0.1)) # Hàm xử lý dữ liệu (Ngưỡng)
model.add(MaxPooling2D((2,2), padding = 'same'))
     
# ANN Model
model.add(Flatten()) # Lấy kích thước trước rồi làm phẳng
model.add(Dense(128, activation = 'linear'))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(classes, activation = 'softmax'))     



model.compile(loss = categorical_crossentropy, optimizer = Adam() , metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  leaky_re_lu (LeakyReLU)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dense (Dense)               (None, 128)               2769024
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2,863,046
# Trainable params: 2,863,046
# Non-trainable params: 0
# _________________________________________________________________

# %%
start = time()
train = model.fit(trainX, trainY, batch_size,epochs=epochs,verbose = 1, validation_data=(valX, valY))
print(time()-start)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 10s 1s/step - loss: 1.7229 - accuracy: 0.2786 - val_loss: 1.5757 - val_accuracy: 0.2836
# Epoch 2/50
# 7/7 [==============================] - 5s 731ms/step - loss: 1.2981 - accuracy: 0.5174 - val_loss: 1.2269 - val_accuracy: 0.5224
# Epoch 3/50
# 7/7 [==============================] - 12s 2s/step - loss: 1.1691 - accuracy: 0.5522 - val_loss: 1.1859 - val_accuracy: 0.4776
# Epoch 4/50
# 7/7 [==============================] - 8s 1s/step - loss: 1.0861 - accuracy: 0.5323 - val_loss: 0.9629 - val_accuracy: 0.5970
# Epoch 5/50
# 7/7 [==============================] - 11s 1s/step - loss: 0.8969 - accuracy: 0.6468 - val_loss: 0.9524 - val_accuracy: 0.6269
# Epoch 6/50
# 7/7 [==============================] - 6s 921ms/step - loss: 0.7916 - accuracy: 0.7363 - val_loss: 1.3181 - val_accuracy: 0.5373
# Epoch 7/50
# 7/7 [==============================] - 9s 1s/step - loss: 0.7559 - accuracy: 0.6716 - val_loss: 1.0048 - val_accuracy: 0.6716
# Epoch 8/50
# 7/7 [==============================] - 5s 739ms/step - loss: 0.5283 - accuracy: 0.8060 - val_loss: 0.9023 - val_accuracy: 0.7015
# Epoch 9/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.3358 - accuracy: 0.9055 - val_loss: 1.3579 - val_accuracy: 0.5970
# Epoch 10/50
# 7/7 [==============================] - 6s 762ms/step - loss: 0.2478 - accuracy: 0.9204 - val_loss: 1.1410 - val_accuracy: 0.6716
# Epoch 11/50
# 7/7 [==============================] - 5s 765ms/step - loss: 0.1306 - accuracy: 0.9801 - val_loss: 1.5155 - val_accuracy: 0.6119
# Epoch 12/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.1264 - accuracy: 0.9652 - val_loss: 1.6600 - val_accuracy: 0.6716
# Epoch 13/50
# 7/7 [==============================] - 5s 731ms/step - loss: 0.1027 - accuracy: 0.9801 - val_loss: 1.7432 - val_accuracy: 0.5672
# Epoch 14/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0607 - accuracy: 0.9851 - val_loss: 1.6739 - val_accuracy: 0.6866
# Epoch 15/50
# 7/7 [==============================] - 5s 756ms/step - loss: 0.0468 - accuracy: 0.9900 - val_loss: 1.8471 - val_accuracy: 0.6866
# Epoch 16/50
# 7/7 [==============================] - 6s 937ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 1.7663 - val_accuracy: 0.6716
# Epoch 17/50
# 7/7 [==============================] - 6s 811ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.7729 - val_accuracy: 0.6418
# Epoch 18/50
# 7/7 [==============================] - 6s 851ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 2.0562 - val_accuracy: 0.6866
# Epoch 19/50
# 7/7 [==============================] - 8s 1s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.2951 - val_accuracy: 0.6567
# Epoch 20/50
# 7/7 [==============================] - 5s 763ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.0356 - val_accuracy: 0.6716
# Epoch 21/50
# 7/7 [==============================] - 7s 1s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.0625 - val_accuracy: 0.6567
# Epoch 22/50
# 7/7 [==============================] - 5s 733ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3364 - val_accuracy: 0.6716
# Epoch 23/50
# 7/7 [==============================] - 6s 865ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.4417 - val_accuracy: 0.6716
# Epoch 24/50
# 7/7 [==============================] - 6s 848ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4388 - val_accuracy: 0.6716
# Epoch 25/50
# 7/7 [==============================] - 5s 762ms/step - loss: 9.4800e-04 - accuracy: 1.0000 - val_loss: 2.4037 - val_accuracy: 0.6716
# Epoch 26/50
# 7/7 [==============================] - 7s 1s/step - loss: 7.9103e-04 - accuracy: 1.0000 - val_loss: 2.3771 - val_accuracy: 0.6716
# Epoch 27/50
# 7/7 [==============================] - 5s 728ms/step - loss: 6.6691e-04 - accuracy: 1.0000 - val_loss: 2.3705 - val_accuracy: 0.6716
# Epoch 28/50
# 7/7 [==============================] - 7s 1s/step - loss: 6.1437e-04 - accuracy: 1.0000 - val_loss: 2.3895 - val_accuracy: 0.6716
# Epoch 29/50
# 7/7 [==============================] - 6s 764ms/step - loss: 5.6659e-04 - accuracy: 1.0000 - val_loss: 2.4130 - val_accuracy: 0.6716
# Epoch 30/50
# 7/7 [==============================] - 5s 738ms/step - loss: 5.2564e-04 - accuracy: 1.0000 - val_loss: 2.4430 - val_accuracy: 0.6716
# Epoch 31/50
# 7/7 [==============================] - 8s 1s/step - loss: 4.8747e-04 - accuracy: 1.0000 - val_loss: 2.4636 - val_accuracy: 0.6716
# Epoch 32/50
# 7/7 [==============================] - 5s 766ms/step - loss: 4.5745e-04 - accuracy: 1.0000 - val_loss: 2.4745 - val_accuracy: 0.6716
# Epoch 33/50
# 7/7 [==============================] - 10s 1s/step - loss: 4.3298e-04 - accuracy: 1.0000 - val_loss: 2.4863 - val_accuracy: 0.6716
# Epoch 34/50
# 7/7 [==============================] - 5s 761ms/step - loss: 4.0903e-04 - accuracy: 1.0000 - val_loss: 2.5024 - val_accuracy: 0.6716
# Epoch 35/50
# 7/7 [==============================] - 7s 995ms/step - loss: 3.8249e-04 - accuracy: 1.0000 - val_loss: 2.5159 - val_accuracy: 0.6716
# Epoch 36/50
# 7/7 [==============================] - 7s 983ms/step - loss: 3.6327e-04 - accuracy: 1.0000 - val_loss: 2.5250 - val_accuracy: 0.6716
# Epoch 37/50
# 7/7 [==============================] - 9s 1s/step - loss: 3.4642e-04 - accuracy: 1.0000 - val_loss: 2.5370 - val_accuracy: 0.6716
# Epoch 38/50
# 7/7 [==============================] - 6s 769ms/step - loss: 3.2835e-04 - accuracy: 1.0000 - val_loss: 2.5519 - val_accuracy: 0.6716
# Epoch 39/50
# 7/7 [==============================] - 5s 721ms/step - loss: 3.1276e-04 - accuracy: 1.0000 - val_loss: 2.5642 - val_accuracy: 0.6716
# Epoch 40/50
# 7/7 [==============================] - 7s 1s/step - loss: 2.9826e-04 - accuracy: 1.0000 - val_loss: 2.5740 - val_accuracy: 0.6716
# Epoch 41/50
# 7/7 [==============================] - 5s 727ms/step - loss: 2.8723e-04 - accuracy: 1.0000 - val_loss: 2.5816 - val_accuracy: 0.6716
# Epoch 42/50
# 7/7 [==============================] - 7s 1s/step - loss: 2.7514e-04 - accuracy: 1.0000 - val_loss: 2.6006 - val_accuracy: 0.6716
# Epoch 43/50
# 7/7 [==============================] - 5s 739ms/step - loss: 2.6292e-04 - accuracy: 1.0000 - val_loss: 2.6145 - val_accuracy: 0.6716
# Epoch 44/50
# 7/7 [==============================] - 5s 758ms/step - loss: 2.5439e-04 - accuracy: 1.0000 - val_loss: 2.6224 - val_accuracy: 0.6716
# Epoch 45/50
# 7/7 [==============================] - 7s 981ms/step - loss: 2.4256e-04 - accuracy: 1.0000 - val_loss: 2.6333 - val_accuracy: 0.6716
# Epoch 46/50
# 7/7 [==============================] - 6s 882ms/step - loss: 2.3111e-04 - accuracy: 1.0000 - val_loss: 2.6320 - val_accuracy: 0.6716
# Epoch 47/50
# 7/7 [==============================] - 8s 1s/step - loss: 2.2283e-04 - accuracy: 1.0000 - val_loss: 2.6422 - val_accuracy: 0.6716
# Epoch 48/50
# 7/7 [==============================] - 5s 775ms/step - loss: 2.1547e-04 - accuracy: 1.0000 - val_loss: 2.6497 - val_accuracy: 0.6716
# Epoch 49/50
# 7/7 [==============================] - 7s 1s/step - loss: 2.0692e-04 - accuracy: 1.0000 - val_loss: 2.6561 - val_accuracy: 0.6716
# Epoch 50/50
# 7/7 [==============================] - 6s 740ms/step - loss: 1.9839e-04 - accuracy: 1.0000 - val_loss: 2.6723 - val_accuracy: 0.6567
# 383.00954937934875

# %%
model.save('/content/drive/MyDrive/TrainAI/Flower/modelflower')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')

plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1.1])
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
acc=train.history['accuracy']
val_acc=train.history['val_accuracy']
loss=train.history['loss']
val_loss=train.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim(0)
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.show()

# %%
name= {1:'daisy', 2:'dandelion',3:'rose',4:'sunflower',5:'tulip'}  
#test
filePath = '/content/drive/MyDrive/TrainAI/Flower/Check/tulip.jpg'
testImage = load_img(filePath, target_size=(img_size,img_size))
arrayImage = img_to_array(testImage).reshape(1,img_size,img_size,3)/255
pred = np.argmax(model.predict(arrayImage))
print("Predicted: ", name[pred])
plt.imshow(testImage)
# Out:
# 1/1 [==============================] - 0s 184ms/step
# Predicted:  rose

# %%
# Tạo một mảng các chỉ số ngẫu nhiên
random_indices = np.random.choice(len(testX), size=68, replace=False)

# Lấy ra 30 mẫu ngẫu nhiên từ tập dữ liệu testX và testY
random_testX = testX[random_indices]
random_testY = testY[random_indices]

# Dùng mô hình để dự đoán nhãn của các mẫu trong tập dữ liệu ngẫu nhiên
results = model.predict(random_testX)
predicted_labels = np.argmax(results, axis=1)

from sklearn.metrics import accuracy_score
# tính độ chính xác 
accuracy = accuracy_score(np.argmax(random_testY, axis=1), predicted_labels)
print("Accuracy:", accuracy*100,"%")
# Out:
# 3/3 [==============================] - 1s 217ms/step
# Accuracy: 63.23529411764706 %
